# %%
import dydx3
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 import dydx3
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\dydx3\__init__.py:1
# ----> 1 from dydx3.dydx_client import Client
#       2 from dydx3.errors import DydxError
#       3 from dydx3.errors import DydxApiError
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\dydx3\dydx_client.py:1
# ----> 1 from web3 import Web3
#       3 from dydx3.constants import DEFAULT_API_TIMEOUT, NETWORK_ID_MAINNET
#       4 from dydx3.eth_signing import SignWithWeb3
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\web3\__init__.py:6
#       2 import warnings
#       4 import pkg_resources
# ----> 6 from eth_account import (
#       7     Account  # noqa: E402,
#       8 )
#       9 from web3.main import (
#      10     Web3  # noqa: E402,
#      11 )
# ...
